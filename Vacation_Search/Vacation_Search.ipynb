# %% [markdown]
# ## Deliverable 2. Create a Customer Travel Destinations Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps
import numpy as np

# Import API key
from config import g_key

# Configure gmaps API key
gmaps.configure(api_key=g_key)

# %%
# 1. Import the WeatherPy_database.csv file. 
city_data_df = pd.read_csv("../Weather_Database/WeatherPy_database.csv")
city_data_df.head()
# Out:
#    City_ID          City Country      Lat       Lng  Max Temp  Humidity  \
# 0        0  Puerto Ayora      EC  -0.7393  -90.3518     82.36        72
# 1        1       Iqaluit      CA  63.7506  -68.5145     10.13        92
# 2        2       Rikitea      PF -23.1203 -134.9692     77.56        72
# 3        3       Ushuaia      AR -54.8000  -68.3000     46.02        81
# 4        4      Lorengau      PG  -2.0226  147.2712     81.37        80
#
#    Cloudiness  Wind Speed Current Description
# 0          88       10.74     overcast clouds
# 1          20        0.00          few clouds
# 2          54        4.72       broken clouds
# 3          40        9.22    scattered clouds
# 4          96        8.25     overcast clouds

# %%
# 2. Prompt the user to enter minimum and maximum temperature criteria 
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
# Out:
# What is the minimum temperature you would like for your trip? 30
# What is the maximum temperature you would like for your trip? 40

# %%
# 3. Filter the city_data_df DataFrame using the input statements to create a new DataFrame using the loc method.
preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & \
                                       (city_data_df["Max Temp"] >= min_temp)]
preferred_cities_df
# Out:
#      City_ID                City Country      Lat       Lng  Max Temp  \
# 43        43            Klaksvik      FO  62.2266   -6.5890     38.32
# 47        47          Nikolskoye      RU  59.7035   30.7861     34.88
# 61        61              Kodiak      US  57.7900 -152.4072     38.71
# 69        69            Olafsvik      IS  64.8945  -23.7142     34.20
# 72        72         South River      US  40.4465  -74.3860     33.15
# 86        86       Ordzhonikidze      KZ  52.4411   61.7408     31.53
# 104      104            Yarovoye      RU  52.9273   78.5800     30.47
# 119      119      Cap-Aux-Meules      CA  47.3821  -61.8597     35.65
# 135      135          Eyrarbakki      IS  63.8630  -21.1481     39.25
# 148      148            Montague      US  42.5356  -72.5351     30.79
# 149      149              Terney      RU  45.0503  136.6092     31.30
# 152      152               Kenai      US  60.5544 -151.2583     34.03
# 190      190       Saint Anthony      US  45.0205  -93.2180     30.92
# 202      202             Dandong      CN  40.1292  124.3947     37.29
# 203      203              Bethel      US  41.3712  -73.4140     30.58
# 213      213           Ilulissat      GL  69.2167  -51.1000     35.62
# 216      216             Parfino      RU  57.9731   31.6481     37.27
# 239      239               Aktau      KZ  43.6500   51.2000     36.18
# 247      247           Bonavista      CA  48.6499  -53.1147     37.09
# 260      260             Zenzeli      RU  45.9241   47.0474     36.12
# 263      263             Trofors      NO  65.5333   13.4063     30.07
# 283      283             Sorland      NO  67.6670   12.6934     33.76
# 298      298             Kewanee      US  41.2456  -89.9248     32.79
# 301      301  Havre-Saint-Pierre      CA  50.2334  -63.5986     30.56
# 324      324           Langxiang      CN  46.9500  128.8833     31.66
# 353      353            Keflavik      IS  64.0049  -22.5624     39.63
# 356      356             Atbasar      KZ  51.8000   68.3333     32.99
# 360      360             Paamiut      GL  61.9940  -49.6678     32.29
# 380      380           Vestmanna      FO  62.1564   -7.1664     36.52
# 386      386               Geilo      NO  60.5333    8.2076     30.70
# 392      392            Evanston      US  42.0411  -87.6901     32.38
# 402      402              Golkoy      TR  40.6875   37.6178     34.20
# 441      441              Nemuro      JP  43.3236  145.5750     31.84
# 449      449             Vrangel      RU  42.7297  133.0839     35.74
# 450      450         Songjianghe      CN  42.1859  127.4790     31.08
# 452      452               Sitka      US  57.0531 -135.3300     35.49
# 459      459          Cheremnoye      RU  53.1697   83.2133     32.59
# 461      461           Harnosand      SE  62.6323   17.9379     32.00
# 467      467               Seoul      KR  37.5683  126.9778     36.84
# 499      499            Qostanay      KZ  53.1667   63.5833     33.78
# 512      512              Urumqi      CN  43.8010   87.6005     38.35
# 540      540     Fort-Shevchenko      KZ  44.5086   50.2630     37.18
# 548      548             Zasosna      RU  50.6307   38.3965     38.41
# 556      556            Meihekou      CN  42.5272  125.6753     39.49
# 567      567          Vanderhoof      CA  54.0166 -124.0198     33.39
# 572      572      Vestmannaeyjar      IS  63.4427  -20.2734     38.39
# 621      621              Juneau      US  58.3019 -134.4197     36.84
# 622      622        Staryy Urukh      RU  43.3404   44.0187     39.58
# 629      629           Ketchikan      US  55.3422 -131.6461     39.15
# 630      630             Gravdal      NO  68.1214   13.5031     31.26
# 638      638             Ardabil      IR  38.2498   48.2933     35.15
# 639      639           Kingisepp      RU  59.3733   28.6134     35.22
# 642      642       Qasigiannguit      GL  68.8193  -51.1922     35.51
# 648      648            Hamilton      US  39.1834  -84.5333     38.21
# 658      658            Fairview      US  40.8126  -73.9990     32.23
# 680      680             Grafton      US  42.2070  -71.6856     30.18
# 685      685        Oktyabrskoye      RU  43.0645   44.7417     30.34
# 692      692             Sarkand      KZ  45.4100   79.9186     37.08
# 703      703           Guzelyurt      TR  38.2772   34.3719     37.45
# 709      709             Yugorsk      RU  61.3133   63.3319     31.24
#
#      Humidity  Cloudiness  Wind Speed Current Description
# 43         72         100       11.68     overcast clouds
# 47         91          65       14.63          light snow
# 61        100         100       13.80       moderate rain
# 69         88         100       16.67                snow
# 72         38          76        8.99       broken clouds
# 86         95         100       13.09     overcast clouds
# 104        97         100        6.51     overcast clouds
# 119        93          40       11.50                 fog
# 135        85         100       12.88     overcast clouds
# 148        38          93       14.05     overcast clouds
# 149        80           3        5.48           clear sky
# 152        85         100       20.71     overcast clouds
# 190        33           0       10.36           clear sky
# 202        61           0        3.65           clear sky
# 203        48         100       13.00     overcast clouds
# 213        44          20       20.71          few clouds
# 216        73          99       14.65     overcast clouds
# 239        47         100       26.19     overcast clouds
# 247        82          85        9.28     overcast clouds
# 260        36          77       14.25       broken clouds
# 263        93         100        2.95                snow
# 283        45         100       27.02     overcast clouds
# 298        26         100        7.63     overcast clouds
# 301       100         100        5.75                mist
# 324        76          89        5.91     overcast clouds
# 353        87         100       19.57     overcast clouds
# 356        95         100       12.57          light snow
# 360        66           1        3.49           clear sky
# 380        87         100        5.75     overcast clouds
# 386        79          94        7.76     overcast clouds
# 392        46          20       10.36          few clouds
# 402        95          82        4.92       broken clouds
# 441        80           7        8.14           clear sky
# 449        75           0        1.77           clear sky
# 450        59          27        8.72    scattered clouds
# 452        80          75        0.00       broken clouds
# 459        96          99        8.16     overcast clouds
# 461        78         100       13.20     overcast clouds
# 467        75           0        2.30           clear sky
# 499        97         100       13.09     overcast clouds
# 512        75           0        4.47           clear sky
# 540        53         100       27.58     overcast clouds
# 548        64          86       22.64     overcast clouds
# 556        35          76       16.28       broken clouds
# 567        77          13        5.14          few clouds
# 572        81         100       34.52     overcast clouds
# 621        90         100        3.44     overcast clouds
# 622        78          71        4.76       broken clouds
# 629        78          83        3.09       broken clouds
# 630        47          97       21.39     overcast clouds
# 638        69          20       16.11                 fog
# 639        82          97       14.61     overcast clouds
# 642        76          22        6.91          few clouds
# 648        46          41        5.01    scattered clouds
# 658        32          75       20.71       broken clouds
# 680        36          61        7.00       broken clouds
# 685        64          97        6.71     overcast clouds
# 692        61          22        7.52          few clouds
# 703        65           5        3.78           clear sky
# 709        96         100        8.28     overcast clouds

# %%
# 4a. Determine if there are any empty rows.

preferred_cities_df.isnull().sum()
# Out:
# City_ID                0
# City                   0
# Country                0
# Lat                    0
# Lng                    0
# Max Temp               0
# Humidity               0
# Cloudiness             0
# Wind Speed             0
# Current Description    0
# dtype: int64

# %%
# 4b. Drop any empty rows and create a new DataFrame that doesn’t have empty rows.
clean_df = preferred_cities_df.dropna()
clean_df
# Out:
#      City_ID                City Country      Lat       Lng  Max Temp  \
# 43        43            Klaksvik      FO  62.2266   -6.5890     38.32
# 47        47          Nikolskoye      RU  59.7035   30.7861     34.88
# 61        61              Kodiak      US  57.7900 -152.4072     38.71
# 69        69            Olafsvik      IS  64.8945  -23.7142     34.20
# 72        72         South River      US  40.4465  -74.3860     33.15
# 86        86       Ordzhonikidze      KZ  52.4411   61.7408     31.53
# 104      104            Yarovoye      RU  52.9273   78.5800     30.47
# 119      119      Cap-Aux-Meules      CA  47.3821  -61.8597     35.65
# 135      135          Eyrarbakki      IS  63.8630  -21.1481     39.25
# 148      148            Montague      US  42.5356  -72.5351     30.79
# 149      149              Terney      RU  45.0503  136.6092     31.30
# 152      152               Kenai      US  60.5544 -151.2583     34.03
# 190      190       Saint Anthony      US  45.0205  -93.2180     30.92
# 202      202             Dandong      CN  40.1292  124.3947     37.29
# 203      203              Bethel      US  41.3712  -73.4140     30.58
# 213      213           Ilulissat      GL  69.2167  -51.1000     35.62
# 216      216             Parfino      RU  57.9731   31.6481     37.27
# 239      239               Aktau      KZ  43.6500   51.2000     36.18
# 247      247           Bonavista      CA  48.6499  -53.1147     37.09
# 260      260             Zenzeli      RU  45.9241   47.0474     36.12
# 263      263             Trofors      NO  65.5333   13.4063     30.07
# 283      283             Sorland      NO  67.6670   12.6934     33.76
# 298      298             Kewanee      US  41.2456  -89.9248     32.79
# 301      301  Havre-Saint-Pierre      CA  50.2334  -63.5986     30.56
# 324      324           Langxiang      CN  46.9500  128.8833     31.66
# 353      353            Keflavik      IS  64.0049  -22.5624     39.63
# 356      356             Atbasar      KZ  51.8000   68.3333     32.99
# 360      360             Paamiut      GL  61.9940  -49.6678     32.29
# 380      380           Vestmanna      FO  62.1564   -7.1664     36.52
# 386      386               Geilo      NO  60.5333    8.2076     30.70
# 392      392            Evanston      US  42.0411  -87.6901     32.38
# 402      402              Golkoy      TR  40.6875   37.6178     34.20
# 441      441              Nemuro      JP  43.3236  145.5750     31.84
# 449      449             Vrangel      RU  42.7297  133.0839     35.74
# 450      450         Songjianghe      CN  42.1859  127.4790     31.08
# 452      452               Sitka      US  57.0531 -135.3300     35.49
# 459      459          Cheremnoye      RU  53.1697   83.2133     32.59
# 461      461           Harnosand      SE  62.6323   17.9379     32.00
# 467      467               Seoul      KR  37.5683  126.9778     36.84
# 499      499            Qostanay      KZ  53.1667   63.5833     33.78
# 512      512              Urumqi      CN  43.8010   87.6005     38.35
# 540      540     Fort-Shevchenko      KZ  44.5086   50.2630     37.18
# 548      548             Zasosna      RU  50.6307   38.3965     38.41
# 556      556            Meihekou      CN  42.5272  125.6753     39.49
# 567      567          Vanderhoof      CA  54.0166 -124.0198     33.39
# 572      572      Vestmannaeyjar      IS  63.4427  -20.2734     38.39
# 621      621              Juneau      US  58.3019 -134.4197     36.84
# 622      622        Staryy Urukh      RU  43.3404   44.0187     39.58
# 629      629           Ketchikan      US  55.3422 -131.6461     39.15
# 630      630             Gravdal      NO  68.1214   13.5031     31.26
# 638      638             Ardabil      IR  38.2498   48.2933     35.15
# 639      639           Kingisepp      RU  59.3733   28.6134     35.22
# 642      642       Qasigiannguit      GL  68.8193  -51.1922     35.51
# 648      648            Hamilton      US  39.1834  -84.5333     38.21
# 658      658            Fairview      US  40.8126  -73.9990     32.23
# 680      680             Grafton      US  42.2070  -71.6856     30.18
# 685      685        Oktyabrskoye      RU  43.0645   44.7417     30.34
# 692      692             Sarkand      KZ  45.4100   79.9186     37.08
# 703      703           Guzelyurt      TR  38.2772   34.3719     37.45
# 709      709             Yugorsk      RU  61.3133   63.3319     31.24
#
#      Humidity  Cloudiness  Wind Speed Current Description
# 43         72         100       11.68     overcast clouds
# 47         91          65       14.63          light snow
# 61        100         100       13.80       moderate rain
# 69         88         100       16.67                snow
# 72         38          76        8.99       broken clouds
# 86         95         100       13.09     overcast clouds
# 104        97         100        6.51     overcast clouds
# 119        93          40       11.50                 fog
# 135        85         100       12.88     overcast clouds
# 148        38          93       14.05     overcast clouds
# 149        80           3        5.48           clear sky
# 152        85         100       20.71     overcast clouds
# 190        33           0       10.36           clear sky
# 202        61           0        3.65           clear sky
# 203        48         100       13.00     overcast clouds
# 213        44          20       20.71          few clouds
# 216        73          99       14.65     overcast clouds
# 239        47         100       26.19     overcast clouds
# 247        82          85        9.28     overcast clouds
# 260        36          77       14.25       broken clouds
# 263        93         100        2.95                snow
# 283        45         100       27.02     overcast clouds
# 298        26         100        7.63     overcast clouds
# 301       100         100        5.75                mist
# 324        76          89        5.91     overcast clouds
# 353        87         100       19.57     overcast clouds
# 356        95         100       12.57          light snow
# 360        66           1        3.49           clear sky
# 380        87         100        5.75     overcast clouds
# 386        79          94        7.76     overcast clouds
# 392        46          20       10.36          few clouds
# 402        95          82        4.92       broken clouds
# 441        80           7        8.14           clear sky
# 449        75           0        1.77           clear sky
# 450        59          27        8.72    scattered clouds
# 452        80          75        0.00       broken clouds
# 459        96          99        8.16     overcast clouds
# 461        78         100       13.20     overcast clouds
# 467        75           0        2.30           clear sky
# 499        97         100       13.09     overcast clouds
# 512        75           0        4.47           clear sky
# 540        53         100       27.58     overcast clouds
# 548        64          86       22.64     overcast clouds
# 556        35          76       16.28       broken clouds
# 567        77          13        5.14          few clouds
# 572        81         100       34.52     overcast clouds
# 621        90         100        3.44     overcast clouds
# 622        78          71        4.76       broken clouds
# 629        78          83        3.09       broken clouds
# 630        47          97       21.39     overcast clouds
# 638        69          20       16.11                 fog
# 639        82          97       14.61     overcast clouds
# 642        76          22        6.91          few clouds
# 648        46          41        5.01    scattered clouds
# 658        32          75       20.71       broken clouds
# 680        36          61        7.00       broken clouds
# 685        64          97        6.71     overcast clouds
# 692        61          22        7.52          few clouds
# 703        65           5        3.78           clear sky
# 709        96         100        8.28     overcast clouds

# %%
# 5a. Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = clean_df[["City", "Country", "Max Temp", "Current Description", "Lat", "Lng"]].copy()

# 5b. Create a new column "Hotel Name"
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#                City Country  Max Temp Current Description      Lat       Lng  \
# 43         Klaksvik      FO     38.32     overcast clouds  62.2266   -6.5890
# 47       Nikolskoye      RU     34.88          light snow  59.7035   30.7861
# 61           Kodiak      US     38.71       moderate rain  57.7900 -152.4072
# 69         Olafsvik      IS     34.20                snow  64.8945  -23.7142
# 72      South River      US     33.15       broken clouds  40.4465  -74.3860
# 86    Ordzhonikidze      KZ     31.53     overcast clouds  52.4411   61.7408
# 104        Yarovoye      RU     30.47     overcast clouds  52.9273   78.5800
# 119  Cap-Aux-Meules      CA     35.65                 fog  47.3821  -61.8597
# 135      Eyrarbakki      IS     39.25     overcast clouds  63.8630  -21.1481
# 148        Montague      US     30.79     overcast clouds  42.5356  -72.5351
#
#     Hotel Name
# 43
# 47
# 61
# 69
# 72
# 86
# 104
# 119
# 135
# 148

# %%
# 6a. Set parameters to search for hotels with 5000 meters.
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}

# 6b. Iterate through the hotel DataFrame.
for index, row in hotel_df.iterrows():
        
    # 6c. Get latitude and longitude from DataFrame
    lat = row["Lat"]
    lng = row["Lng"]
    params["location"] = f"{lat},{lng}"
    
    # 6d. Set up the base URL for the Google Directions API to get JSON data.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    # 6e. Make request and retrieve the JSON data from the search. 
    hotels = requests.get(base_url, params=params).json()
    
    # 6f. Get the first hotel from the results and store the name, if a hotel isn't found skip the city.
    try:
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
    except (IndexError):
        print("Hotel not found... skipping.")
# Out:
# Hotel not found... skipping.

# %%
# 7. Drop the rows where there is no Hotel Name.
hotel_df.loc[hotel_df["Hotel Name"] == ""] = np.nan
clean_hotel_df = hotel_df.dropna()
clean_hotel_df
# Out:
#                    City Country  Max Temp Current Description      Lat  \
# 43             Klaksvik      FO     38.32     overcast clouds  62.2266
# 47           Nikolskoye      RU     34.88          light snow  59.7035
# 61               Kodiak      US     38.71       moderate rain  57.7900
# 69             Olafsvik      IS     34.20                snow  64.8945
# 72          South River      US     33.15       broken clouds  40.4465
# 86        Ordzhonikidze      KZ     31.53     overcast clouds  52.4411
# 104            Yarovoye      RU     30.47     overcast clouds  52.9273
# 119      Cap-Aux-Meules      CA     35.65                 fog  47.3821
# 135          Eyrarbakki      IS     39.25     overcast clouds  63.8630
# 148            Montague      US     30.79     overcast clouds  42.5356
# 149              Terney      RU     31.30           clear sky  45.0503
# 152               Kenai      US     34.03     overcast clouds  60.5544
# 190       Saint Anthony      US     30.92           clear sky  45.0205
# 202             Dandong      CN     37.29           clear sky  40.1292
# 203              Bethel      US     30.58     overcast clouds  41.3712
# 213           Ilulissat      GL     35.62          few clouds  69.2167
# 216             Parfino      RU     37.27     overcast clouds  57.9731
# 239               Aktau      KZ     36.18     overcast clouds  43.6500
# 247           Bonavista      CA     37.09     overcast clouds  48.6499
# 260             Zenzeli      RU     36.12       broken clouds  45.9241
# 263             Trofors      NO     30.07                snow  65.5333
# 283             Sorland      NO     33.76     overcast clouds  67.6670
# 298             Kewanee      US     32.79     overcast clouds  41.2456
# 301  Havre-Saint-Pierre      CA     30.56                mist  50.2334
# 324           Langxiang      CN     31.66     overcast clouds  46.9500
# 353            Keflavik      IS     39.63     overcast clouds  64.0049
# 356             Atbasar      KZ     32.99          light snow  51.8000
# 360             Paamiut      GL     32.29           clear sky  61.9940
# 380           Vestmanna      FO     36.52     overcast clouds  62.1564
# 386               Geilo      NO     30.70     overcast clouds  60.5333
# 392            Evanston      US     32.38          few clouds  42.0411
# 402              Golkoy      TR     34.20       broken clouds  40.6875
# 441              Nemuro      JP     31.84           clear sky  43.3236
# 449             Vrangel      RU     35.74           clear sky  42.7297
# 450         Songjianghe      CN     31.08    scattered clouds  42.1859
# 452               Sitka      US     35.49       broken clouds  57.0531
# 461           Harnosand      SE     32.00     overcast clouds  62.6323
# 467               Seoul      KR     36.84           clear sky  37.5683
# 499            Qostanay      KZ     33.78     overcast clouds  53.1667
# 512              Urumqi      CN     38.35           clear sky  43.8010
# 540     Fort-Shevchenko      KZ     37.18     overcast clouds  44.5086
# 548             Zasosna      RU     38.41     overcast clouds  50.6307
# 556            Meihekou      CN     39.49       broken clouds  42.5272
# 567          Vanderhoof      CA     33.39          few clouds  54.0166
# 572      Vestmannaeyjar      IS     38.39     overcast clouds  63.4427
# 621              Juneau      US     36.84     overcast clouds  58.3019
# 622        Staryy Urukh      RU     39.58       broken clouds  43.3404
# 629           Ketchikan      US     39.15       broken clouds  55.3422
# 630             Gravdal      NO     31.26     overcast clouds  68.1214
# 638             Ardabil      IR     35.15                 fog  38.2498
# 639           Kingisepp      RU     35.22     overcast clouds  59.3733
# 642       Qasigiannguit      GL     35.51          few clouds  68.8193
# 648            Hamilton      US     38.21    scattered clouds  39.1834
# 658            Fairview      US     32.23       broken clouds  40.8126
# 680             Grafton      US     30.18       broken clouds  42.2070
# 685        Oktyabrskoye      RU     30.34     overcast clouds  43.0645
# 692             Sarkand      KZ     37.08          few clouds  45.4100
# 703           Guzelyurt      TR     37.45           clear sky  38.2772
# 709             Yugorsk      RU     31.24     overcast clouds  61.3133
#
#           Lng                                         Hotel Name
# 43    -6.5890                                       Airbnb rooms
# 47    30.7861                            Tourist House - Sablino
# 61  -152.4072      Best Western Kodiak Inn And Convention Center
# 69   -23.7142                                     Hotel Olafsvik
# 72   -74.3860  Holiday Inn Express & Suites Tower Center New ...
# 86    61.7408                                            Tomiris
# 104   78.5800                                        KirOFF Park
# 119  -61.8597                                  Château Madelinot
# 135  -21.1481                                      Guesthouse 77
# 148  -72.5351                       Two Rivers Bed and Breakfast
# 149  136.6092                                     Hotel "Ternay"
# 152 -151.2583                         Aspen Extended Stay Suites
# 190  -93.2180  Holiday Inn Express Roseville-St. Paul, an IHG...
# 202  124.3947                                   Yiranju Farmstay
# 203  -73.4140                      Courtyard by Marriott Danbury
# 213  -51.1000                                       Hotel Arctic
# 216   31.6481                              Zabava U Sergeyevicha
# 239   51.2000                                     Silk Way Hotel
# 247  -53.1147                                  Sweet Sharons bnb
# 260   47.0474                             Gostinitsa "Zvezdnaya"
# 263   13.4063                                      Utpå Neset AS
# 283   12.6934                                Sjybrygga fiskecamp
# 298  -89.9248                       AmericInn by Wyndham Kewanee
# 301  -63.5986                                  Auberge Niapiskau
# 324  128.8833                                        Pearl Hotel
# 353  -22.5624                                     Hotel Keflavik
# 356   68.3333                          Гостиничный Комплекс Saad
# 360  -49.6678                                             Pistut
# 380   -7.1664                                  Vestmanna Camping
# 386    8.2076                               Havsdalsgrenda Geilo
# 392  -87.6901     Hilton Garden Inn Chicago North Shore/Evanston
# 402   37.6178                                 Golkoy Ogretmenevi
# 441  145.5750                             Hotel Nemuro Kaiyoutei
# 449  133.0839                                       Отель "БАЛИ"
# 450  127.4790                      Sijisheng Fashion Guest House
# 452 -135.3300                                     Westmark Sitka
# 461   17.9379                                  First Hotel Stadt
# 467  126.9778                                            롯데호텔 서울
# 499   63.5833                                       Hotel Fessla
# 512   87.6005                        Hua Ling Grand Hotel Urumqi
# 540   50.2630                                Oasis hotel Bautino
# 548   38.3965                                            Biryuch
# 556  125.6753                                               如家宾馆
# 567 -124.0198                                     Vanderhoof Inn
# 572  -20.2734                                 Glamping & Camping
# 621 -134.4197          Baranof Downtown, BW Signature Collection
# 622   44.0187                                 Комната для намаза
# 629 -131.6461                                  Snow's Cove Lodge
# 630   13.5031                                 Skreda Rorbusuiter
# 638   48.2933                                        Hotel ideal
# 639   28.6134                                              Narva
# 642  -51.1922                                        Almost HOME
# 648  -84.5333                          Six Acres Bed & Breakfast
# 658  -73.9990       Homewood Suites by Hilton Edgewater-NYC Area
# 680  -71.6856                                    The Grafton Inn
# 685   44.7417                                Prolesok Mini-hotel
# 692   79.9186                                  Гостиница Сарканд
# 703   34.3719                         Cappadocia Ihlara Mansions
# 709   63.3319                              Arkobaleno Mini-hotel

# %%
# 8a. Create the output File (CSV)
output_data_file = "WeatherPy_vacation.csv"
# 8b. Export the City_Data into a csv
clean_hotel_df.to_csv(output_data_file, index_label="City_ID")

# %%
clean_hotel_df
# Out:
#                    City Country  Max Temp Current Description      Lat  \
# 43             Klaksvik      FO     38.32     overcast clouds  62.2266
# 47           Nikolskoye      RU     34.88          light snow  59.7035
# 61               Kodiak      US     38.71       moderate rain  57.7900
# 69             Olafsvik      IS     34.20                snow  64.8945
# 72          South River      US     33.15       broken clouds  40.4465
# 86        Ordzhonikidze      KZ     31.53     overcast clouds  52.4411
# 104            Yarovoye      RU     30.47     overcast clouds  52.9273
# 119      Cap-Aux-Meules      CA     35.65                 fog  47.3821
# 135          Eyrarbakki      IS     39.25     overcast clouds  63.8630
# 148            Montague      US     30.79     overcast clouds  42.5356
# 149              Terney      RU     31.30           clear sky  45.0503
# 152               Kenai      US     34.03     overcast clouds  60.5544
# 190       Saint Anthony      US     30.92           clear sky  45.0205
# 202             Dandong      CN     37.29           clear sky  40.1292
# 203              Bethel      US     30.58     overcast clouds  41.3712
# 213           Ilulissat      GL     35.62          few clouds  69.2167
# 216             Parfino      RU     37.27     overcast clouds  57.9731
# 239               Aktau      KZ     36.18     overcast clouds  43.6500
# 247           Bonavista      CA     37.09     overcast clouds  48.6499
# 260             Zenzeli      RU     36.12       broken clouds  45.9241
# 263             Trofors      NO     30.07                snow  65.5333
# 283             Sorland      NO     33.76     overcast clouds  67.6670
# 298             Kewanee      US     32.79     overcast clouds  41.2456
# 301  Havre-Saint-Pierre      CA     30.56                mist  50.2334
# 324           Langxiang      CN     31.66     overcast clouds  46.9500
# 353            Keflavik      IS     39.63     overcast clouds  64.0049
# 356             Atbasar      KZ     32.99          light snow  51.8000
# 360             Paamiut      GL     32.29           clear sky  61.9940
# 380           Vestmanna      FO     36.52     overcast clouds  62.1564
# 386               Geilo      NO     30.70     overcast clouds  60.5333
# 392            Evanston      US     32.38          few clouds  42.0411
# 402              Golkoy      TR     34.20       broken clouds  40.6875
# 441              Nemuro      JP     31.84           clear sky  43.3236
# 449             Vrangel      RU     35.74           clear sky  42.7297
# 450         Songjianghe      CN     31.08    scattered clouds  42.1859
# 452               Sitka      US     35.49       broken clouds  57.0531
# 461           Harnosand      SE     32.00     overcast clouds  62.6323
# 467               Seoul      KR     36.84           clear sky  37.5683
# 499            Qostanay      KZ     33.78     overcast clouds  53.1667
# 512              Urumqi      CN     38.35           clear sky  43.8010
# 540     Fort-Shevchenko      KZ     37.18     overcast clouds  44.5086
# 548             Zasosna      RU     38.41     overcast clouds  50.6307
# 556            Meihekou      CN     39.49       broken clouds  42.5272
# 567          Vanderhoof      CA     33.39          few clouds  54.0166
# 572      Vestmannaeyjar      IS     38.39     overcast clouds  63.4427
# 621              Juneau      US     36.84     overcast clouds  58.3019
# 622        Staryy Urukh      RU     39.58       broken clouds  43.3404
# 629           Ketchikan      US     39.15       broken clouds  55.3422
# 630             Gravdal      NO     31.26     overcast clouds  68.1214
# 638             Ardabil      IR     35.15                 fog  38.2498
# 639           Kingisepp      RU     35.22     overcast clouds  59.3733
# 642       Qasigiannguit      GL     35.51          few clouds  68.8193
# 648            Hamilton      US     38.21    scattered clouds  39.1834
# 658            Fairview      US     32.23       broken clouds  40.8126
# 680             Grafton      US     30.18       broken clouds  42.2070
# 685        Oktyabrskoye      RU     30.34     overcast clouds  43.0645
# 692             Sarkand      KZ     37.08          few clouds  45.4100
# 703           Guzelyurt      TR     37.45           clear sky  38.2772
# 709             Yugorsk      RU     31.24     overcast clouds  61.3133
#
#           Lng                                         Hotel Name
# 43    -6.5890                                       Airbnb rooms
# 47    30.7861                            Tourist House - Sablino
# 61  -152.4072      Best Western Kodiak Inn And Convention Center
# 69   -23.7142                                     Hotel Olafsvik
# 72   -74.3860  Holiday Inn Express & Suites Tower Center New ...
# 86    61.7408                                            Tomiris
# 104   78.5800                                        KirOFF Park
# 119  -61.8597                                  Château Madelinot
# 135  -21.1481                                      Guesthouse 77
# 148  -72.5351                       Two Rivers Bed and Breakfast
# 149  136.6092                                     Hotel "Ternay"
# 152 -151.2583                         Aspen Extended Stay Suites
# 190  -93.2180  Holiday Inn Express Roseville-St. Paul, an IHG...
# 202  124.3947                                   Yiranju Farmstay
# 203  -73.4140                      Courtyard by Marriott Danbury
# 213  -51.1000                                       Hotel Arctic
# 216   31.6481                              Zabava U Sergeyevicha
# 239   51.2000                                     Silk Way Hotel
# 247  -53.1147                                  Sweet Sharons bnb
# 260   47.0474                             Gostinitsa "Zvezdnaya"
# 263   13.4063                                      Utpå Neset AS
# 283   12.6934                                Sjybrygga fiskecamp
# 298  -89.9248                       AmericInn by Wyndham Kewanee
# 301  -63.5986                                  Auberge Niapiskau
# 324  128.8833                                        Pearl Hotel
# 353  -22.5624                                     Hotel Keflavik
# 356   68.3333                          Гостиничный Комплекс Saad
# 360  -49.6678                                             Pistut
# 380   -7.1664                                  Vestmanna Camping
# 386    8.2076                               Havsdalsgrenda Geilo
# 392  -87.6901     Hilton Garden Inn Chicago North Shore/Evanston
# 402   37.6178                                 Golkoy Ogretmenevi
# 441  145.5750                             Hotel Nemuro Kaiyoutei
# 449  133.0839                                       Отель "БАЛИ"
# 450  127.4790                      Sijisheng Fashion Guest House
# 452 -135.3300                                     Westmark Sitka
# 461   17.9379                                  First Hotel Stadt
# 467  126.9778                                            롯데호텔 서울
# 499   63.5833                                       Hotel Fessla
# 512   87.6005                        Hua Ling Grand Hotel Urumqi
# 540   50.2630                                Oasis hotel Bautino
# 548   38.3965                                            Biryuch
# 556  125.6753                                               如家宾馆
# 567 -124.0198                                     Vanderhoof Inn
# 572  -20.2734                                 Glamping & Camping
# 621 -134.4197          Baranof Downtown, BW Signature Collection
# 622   44.0187                                 Комната для намаза
# 629 -131.6461                                  Snow's Cove Lodge
# 630   13.5031                                 Skreda Rorbusuiter
# 638   48.2933                                        Hotel ideal
# 639   28.6134                                              Narva
# 642  -51.1922                                        Almost HOME
# 648  -84.5333                          Six Acres Bed & Breakfast
# 658  -73.9990       Homewood Suites by Hilton Edgewater-NYC Area
# 680  -71.6856                                    The Grafton Inn
# 685   44.7417                                Prolesok Mini-hotel
# 692   79.9186                                  Гостиница Сарканд
# 703   34.3719                         Cappadocia Ihlara Mansions
# 709   63.3319                              Arkobaleno Mini-hotel

# %%
# 9. Using the template add city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Weather</dt><dd>{Current Description} and {Max Temp}*F</dd>
</dl>
"""

# 10a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in clean_hotel_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = clean_hotel_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map. 

fig = gmaps.figure(center=(20.0, 25.0), zoom_level=1)

marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)

fig.add_layer(marker_layer)
# 11b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Save the figure.

#Currently images cannot be exported to PNG using code. 
#It has to be done manually using download option from the image generated above

#below code is to save image as html
from ipywidgets.embed import embed_minimal_html
embed_minimal_html('WeatherPy_vacation_map.html', views=[fig])
